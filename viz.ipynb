# %%
import matplotlib.pyplot as plt
import torch

# %%
pos,neg = torch.load('scores.pt', weights_only=False)
pos = pos.sort().values.to('cpu')
neg = neg.sort().values.to('cpu')

# %%
plt.hist(pos, 100, color='C0')
plt.hist(neg, 100, color='C1')
plt.show()
